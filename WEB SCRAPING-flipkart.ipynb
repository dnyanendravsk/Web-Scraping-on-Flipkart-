# %% [markdown]
# # import libraries for web scraping

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
url = urlopen("https://www.flipkart.com/lenovo-ideapad-3-core-i3-10th-gen-8-gb-256-gb-ssd-windows-11-home-15iml05-thin-light-laptop/p/itmd1871bfcde765?pid=COMG6AKVAHWTHAQG&lid=LSTCOMG6AKVAHWTHAQGXUICJF&marketplace=FLIPKART&q=lenovo+laptop&store=6bo%2Fb5g&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&fm=search-autosuggest&iid=04a7e7a6-7a61-41a8-816d-51ec8d14fc6e.COMG6AKVAHWTHAQG.SEARCH&ppt=clp&ppn=laptops-store&ssid=jew1e2gy0w0000001648368818116&qH=86f3cf6b571c1490")
data = url.read()
print(data)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6e7580.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
soupdata = soup(data)

# %%
soupdata
# Out:
# <!DOCTYPE html>
# ...

# %%
brand_name = soupdata.findAll('div',{'class':'_3GIHBu'})[3].text
brand_name
# Out:
# 'Lenovo Laptops'

# %%
brand_name
# Out:
# 'Lenovo Laptops'

# %%
name = soupdata.findAll('span',{'class':'B_NuCI'})[0].text.split('-')[0]
name
# Out:
# 'Lenovo IdeaPad 3 Core i3 10th Gen '

# %%
features = soupdata.findAll('span',{'class':'B_NuCI'})[0].text.split('-')[1]
features
# Out:
# ' (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop\xa0\xa0(15.6 Inch, Platinum Grey, 1.7 kg, With MS Office)'

# %%
price = soupdata.findAll('div',{'class':'_30jeq3 _16Jk6d'})[0].text
price
# Out:
# '₹34,490'

# %%
review = soupdata.find('span',{'class':'_2_R_DZ'}).text
print((review))
# Out:
# 2,381 Ratings & 260 Reviews

# %%
import re
review = re.findall('\d+,?\d*','2,069 Ratings\xa0&\xa0232 Reviews')[1]
review
# Out:
# '232'

# %%
print(brand_name,name,price,review)
# Out:
# Lenovo Laptops Lenovo IdeaPad 3 Core i3 10th Gen  ₹34,490 232

# %%
flipkart = (f"{brand_name},{name},{price},{review}")

# %%
f = open("E:/flipkart_web_scrabing.csv",'wb')
f.write("brand_name,name,price,review\n".encode())

brand_name = soupdata.findAll('div',{'class':'_3GIHBu'})[3].text
name = soupdata.findAll('span',{'class':'B_NuCI'})[0].text.split('-')[0]
price = soupdata.findAll('div',{'class':'_30jeq3 _16Jk6d'})[0].text.replace(',','')

review = soupdata.find('span',{'class':'_2_R_DZ'}).text
import re
review = re.findall('\d+,?\d*','2,069 Ratings\xa0&\xa0232 Reviews')[1]


print(brand_name,name,price,review)
f.write(f"{brand_name},{name},{price},{review}".encode())
f.close()
#flipkart.to_csv("E:/flipkart_eb_scrabing.csv",'wb')
# Out:
# Lenovo Laptops Lenovo IdeaPad 3 Core i3 10th Gen  ₹34490 232

# %%
import pandas as pd
A = pd.read_csv("E:/flipkart_web_scrabing.csv")

# %%
A
# Out:
#        brand_name                                name   price  review
# 0  Lenovo Laptops  Lenovo IdeaPad 3 Core i3 10th Gen   ₹34490     232
